# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.font_manager as fm
import matplotlib.image as mpimg

# Load base image (use your own path or skip if no base image)
# If no base image, comment next two lines
# img = mpimg.imread('architecture.png')
# base_img_available = True
base_img_available = False  # Change to True if you load an image

# Common figure size
figsize = (14, 10)

# -- First Image: ETL Pipeline Layers --

fig, ax = plt.subplots(figsize=figsize)
if base_img_available:
    ax.imshow(img)

ax.axis('off')

# Define ETL pipeline layers (x, y, width, height, label, color)
layers = [
    (50, 50, 160, 50, 'Layer 1: Data Collection (CSV, API, Scraping)', '#f4a261'),        # Orange
    (250, 50, 160, 50, 'Layer 2: Data Cleaning & Preparation (Pandas, NumPy)', '#2a9d8f'), # Teal
    (450, 50, 180, 50, 'Layer 3: Cleaned DataFrame', '#e9c46a'),                          # Yellow
    (50, 150, 180, 50, 'Layer 4: Data Storage (SQLite DB)', '#264653'),                   # Dark Blue
    (270, 150, 140, 50, 'Layer 5: Data Visualization (Matplotlib, Seaborn)', '#f4a261'),   # Orange
    (450, 150, 180, 50, 'Layer 6: Containerization (Docker)', '#e76f51'),                  # Red-Orange
    (50, 260, 200, 50, 'Layer 7: Workflow Automation (Cron Jobs)', '#2a9d8f'),             # Teal
]

# Draw rectangles and labels
for x, y, w, h, label, color in layers:
    rect = patches.FancyBboxPatch((x, y), w, h, boxstyle="round,pad=0.05", linewidth=2, edgecolor='black', facecolor=color)
    ax.add_patch(rect)
    ax.text(x + w/2, y + h/2, label, ha='center', va='center', fontsize=12, weight='bold', color='white')

plt.title("ETL Pipeline Layers", fontsize=18, weight='bold')
plt.savefig('architecture_full_pipeline_professional.png', bbox_inches='tight', dpi=300)
plt.show()

# -- Second Image: Tools Used --

fig, ax = plt.subplots(figsize=(12, 7))
ax.axis('off')

# Tools info, positions (x, y), label, and color blocks
tools = [
    (50, 50, 'Data Collection:\nCSV, Public APIs, Web Scraping', '#f4a261'),
    (300, 50, 'Data Cleaning:\nPandas, NumPy', '#2a9d8f'),
    (520, 50, 'Storage:\nSQLite DB', '#264653'),
    (50, 140, 'Visualization:\nMatplotlib, Seaborn', '#e9c46a'),
    (300, 140, 'Containerization:\nDocker', '#e76f51'),
    (520, 140, 'Automation:\nCron Jobs', '#2a9d8f'),
    (270, 230, 'Bonus:\nEmail Alerts (SMTP)', '#f4a261'),
]

for x, y, label, color in tools:
    rect = patches.FancyBboxPatch((x, y), 220, 70, boxstyle="round,pad=0.05", linewidth=2, edgecolor='black', facecolor=color)
    ax.add_patch(rect)
    ax.text(x + 110, y + 35, label, ha='center', va='center', fontsize=13, weight='bold', color='white')

plt.title("Tools Used in Project", fontsize=18, weight='bold')
plt.savefig('architecture_tools_used_professional.png', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
# findfont: Font family 'Apple Color Emoji' not found.
