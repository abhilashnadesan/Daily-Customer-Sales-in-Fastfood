# %%
import pandas as pd

# Step 1: Load the data
file_path = "../data/raw/sales_data.csv"
df = pd.read_csv(file_path)

# Show first few rows
print("Shape of data:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 # Step 1: Load the data
#       4 file_path = "../data/raw/sales_data.csv"
# ----> 5 df = pd.read_csv(file_path)
#       7 # Show first few rows
#       8 print("Shape of data:", df.shape)
#
# ...

# %%
import pandas as pd

# Step 1: Load the data
file_path = "../data/raw/DAILY CUSTOMER SALES IN FAST FOOD OUTLETS.csv"
df = pd.read_csv(file_path)

# Show first few rows
print("Shape of data:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       3 # Step 1: Load the data
#       4 file_path = "../data/raw/DAILY CUSTOMER SALES IN FAST FOOD OUTLETS.csv"
# ----> 5 df = pd.read_csv(file_path)
#       7 # Show first few rows
#       8 print("Shape of data:", df.shape)
#
# ...

# %%
import pandas as pd

# Step 1: Load the data
file_path = "../data/raw/sales_data.csv"
df = pd.read_csv(file_path)

# Show first few rows
print("Shape of data:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 5
#       3 # Step 1: Load the data
#       4 file_path = "../data/raw/sales_data.csv"
# ----> 5 df = pd.read_csv(file_path)
#       7 # Show first few rows
#       8 print("Shape of data:", df.shape)
#
# ...

# %%
import pandas as pd

# Load the dataset
file_path = "/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/data/raw/sales_data.csv"
df = pd.read_csv(file_path)

# Preview
print("Shape of data:", df.shape)
df.head()
# Out:
# Shape of data: (10183, 7)
#    Age  Gender   OrderedItem       When Order Type  Unnamed: 5 Unnamed: 6
# 0   36     1.0         Chips  Afternoon     Eat In         NaN        NaN
# 1   42     1.0     White Tea    Morning     Eat In         NaN        NaN
# 2   23     1.0     Black Tea    Morning     Eat In         NaN        NaN
# 3   23     0.0         Kebab  Afternoon     Eat In         NaN        NaN
# 4   38     1.0  Chips Masala  Afternoon     Eat In         NaN        NaN

# %%
# Clean and transform

# Normalize column names
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]

# Convert dates/times
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['hour'] = pd.to_datetime(df['time'], errors='coerce').dt.hour
df['day_of_week'] = df['date'].dt.day_name()

# Remove missing rows
df = df.dropna()

# Preview
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 7
# ...

# %%
print(df.columns.tolist())
# Out:
# ['age', 'gender', 'ordereditem', 'when', 'order_type', 'unnamed:_5', 'unnamed:_6']

# %%
['Date ', ' Time', 'Item', 'Total Price', 'Outlet']
# Out:
# ['Date ', ' Time', 'Item', 'Total Price', 'Outlet']

# %%
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]
print(df.columns.tolist())  # To double-check
# Out:
# ['age', 'gender', 'ordereditem', 'when', 'order_type', 'unnamed:_5', 'unnamed:_6']

# %%
['date', 'time', 'item', 'total_price', 'outlet']
# Out:
# ['date', 'time', 'item', 'total_price', 'outlet']

# %%
# Convert date and time
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['hour'] = pd.to_datetime(df['time'], errors='coerce').dt.hour
df['day_of_week'] = df['date'].dt.day_name()

# Drop rows with any missing values
df = df.dropna()
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Convert date and time
# ...

# %%
import pandas as pd

# Step 1: Load the dataset
file_path = "/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily_fastfood_project/data/raw/sales_data.csv"
df = pd.read_csv(file_path)

# Step 2: Normalize column names first
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]
print("Cleaned column names:", df.columns.tolist())

# Step 3: Convert dates and times
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['hour'] = pd.to_datetime(df['time'], errors='coerce').dt.hour
df['day_of_week'] = df['date'].dt.day_name()

# Step 4: Drop rows with any missing values
df = df.dropna()

# Step 5: Preview cleaned data
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 5
#       3 # Step 1: Load the dataset
#       4 file_path = "/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily_fastfood_project/data/raw/sales_data.csv"
# ----> 5 df = pd.read_csv(file_path)
#       7 # Step 2: Normalize column names first
#       8 df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]
#
# ...

# %%
import pandas as pd

# Step 1: Load the dataset
file_path = "/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/data/raw/sales_data.csv"
df = pd.read_csv(file_path)

# Step 2: Normalize column names first
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]
print("Cleaned column names:", df.columns.tolist())

# Step 3: Convert dates and times
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['hour'] = pd.to_datetime(df['time'], errors='coerce').dt.hour
df['day_of_week'] = df['date'].dt.day_name()

# Step 4: Drop rows with any missing values
df = df.dropna()

# Step 5: Preview cleaned data
df.head()
# Out:
# Cleaned column names: ['age', 'gender', 'ordereditem', 'when', 'order_type', 'unnamed:_5', 'unnamed:_6']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Step 1: Drop empty columns
df = df.drop(columns=["Unnamed: 5", "Unnamed: 6"])

# Step 2: Clean column names
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]

# Step 3: Drop any missing rows
df = df.dropna()

# Step 4: Preview
print("Cleaned Columns:", df.columns.tolist())
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Step 1: Drop empty columns
# ----> 2 df = df.drop(columns=["Unnamed: 5", "Unnamed: 6"])
#       4 # Step 2: Clean column names
#       5 df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
# ...

# %%
print("Columns in dataset:", df.columns.tolist())
df.head()
# Out:
# Columns in dataset: ['age', 'gender', 'ordereditem', 'when', 'order_type', 'unnamed:_5', 'unnamed:_6']
#    age  gender   ordereditem       when order_type  unnamed:_5 unnamed:_6
# 0   36     1.0         Chips  Afternoon     Eat In         NaN        NaN
# 1   42     1.0     White Tea    Morning     Eat In         NaN        NaN
# 2   23     1.0     Black Tea    Morning     Eat In         NaN        NaN
# 3   23     0.0         Kebab  Afternoon     Eat In         NaN        NaN
# 4   38     1.0  Chips Masala  Afternoon     Eat In         NaN        NaN

# %%
Columns in dataset: ['order_id', 'outlet', 'item', 'quantity', 'timestamp', 'time']
# Out:
#   Cell In[34], line 1
#     Columns in dataset: ['order_id', 'outlet', 'item', 'quantity', 'timestamp', 'time']
#     ^
# SyntaxError: illegal target for annotation

# %%
# Assume 'timestamp' is the correct datetime column
df['date'] = pd.to_datetime(df['timestamp'], errors='coerce')
df['hour'] = pd.to_datetime(df['time'], errors='coerce').dt.hour
df['day_of_week'] = df['date'].dt.day_name()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Assume 'timestamp' is the correct datetime column
# ...

# %%
# Step 2: Clean and transform data

# Normalize column names
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]

# Parse date and time
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['hour'] = pd.to_datetime(df['time'], errors='coerce').dt.hour
df['day_of_week'] = df['date'].dt.day_name()

# Drop any rows with missing data
df = df.dropna()

# Preview again
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 7
# ...

# %%
# Show all column names
print("📌 Column Names:", df.columns.tolist())

# Show a preview of the data
df.head()
# Out:
# 📌 Column Names: ['age', 'gender', 'ordereditem', 'when', 'order_type', 'unnamed:_5', 'unnamed:_6']
#    age  gender   ordereditem       when order_type  unnamed:_5 unnamed:_6
# 0   36     1.0         Chips  Afternoon     Eat In         NaN        NaN
# 1   42     1.0     White Tea    Morning     Eat In         NaN        NaN
# 2   23     1.0     Black Tea    Morning     Eat In         NaN        NaN
# 3   23     0.0         Kebab  Afternoon     Eat In         NaN        NaN
# 4   38     1.0  Chips Masala  Afternoon     Eat In         NaN        NaN

# %%
# Step 1: Drop unnecessary columns
df = df.drop(columns=["unnamed:_5", "unnamed:_6"])

# Step 2: Clean column names
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]

# Step 3: Drop missing rows
df = df.dropna()

# Step 4: Rename and engineer features
df = df.rename(columns={'ordereditem': 'item'})  # More readable

# Step 5: Simulate 'hour' column based on 'when'
# We'll map part-of-day to hour ranges for visualization
when_to_hour = {
    'Morning': 9,
    'Afternoon': 14,
    'Evening': 18,
    'Night': 21
}
df['hour'] = df['when'].map(when_to_hour)

# Step 6: Fake 'date' column just for visuals (all on same date for example)
df['date'] = pd.to_datetime("2025-05-01")
df['day_of_week'] = df['date'].dt.day_name()

# Final preview
df.head()
# Out:
#    age  gender          item       when order_type  hour       date  \
# 0   36     1.0         Chips  Afternoon     Eat In  14.0 2025-05-01
# 1   42     1.0     White Tea    Morning     Eat In   9.0 2025-05-01
# 2   23     1.0     Black Tea    Morning     Eat In   9.0 2025-05-01
# 3   23     0.0         Kebab  Afternoon     Eat In  14.0 2025-05-01
# 4   38     1.0  Chips Masala  Afternoon     Eat In  14.0 2025-05-01
#
#   day_of_week
# 0    Thursday
# 1    Thursday
# 2    Thursday
# 3    Thursday
# 4    Thursday

# %%
import sqlite3

# Save to database
db_path = "/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/db/sales_data.db"
conn = sqlite3.connect(db_path)

df.to_sql("fastfood_sales", conn, if_exists="replace", index=False)
conn.close()

print("Data saved to SQLite.")
# Out:
# Data saved to SQLite.

# %%
import matplotlib.pyplot as plt

outlet_sales = df.groupby('outlet')['total_price'].sum().sort_values()

plt.figure(figsize=(10,5))
outlet_sales.plot(kind='barh', color='skyblue')
plt.title("Total Sales by Outlet")
plt.xlabel("Total Sales")
plt.ylabel("Outlet")
plt.tight_layout()
plt.savefig("/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/sales_by_outlet.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 outlet_sales = df.groupby('outlet')['total_price'].sum().sort_values()
#       5 plt.figure(figsize=(10,5))
#       6 outlet_sales.plot(kind='barh', color='skyblue')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Rename column for clarity (if not done yet)
df = df.rename(columns={'ordereditem': 'item'})

# Count item frequency by part of day
item_when = df.groupby(['when', 'item']).size().unstack().fillna(0)

# Plot
plt.figure(figsize=(12, 6))
item_when.plot(kind='bar', stacked=True, colormap='tab20', figsize=(12, 6))
plt.title("Items Ordered by Time of Day")
plt.ylabel("Number of Orders")
plt.xlabel("Time of Day")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
sales_by_day = df.groupby('day_of_week')['total_price'].sum().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

plt.figure(figsize=(8,5))
sales_by_day.plot(kind='bar', color='lightgreen')
plt.title("Sales by Day of Week")
plt.ylabel("Total Sales")
plt.xlabel("Day")
plt.tight_layout()
plt.savefig("/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/sales_by_day.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 sales_by_day = df.groupby('day_of_week')['total_price'].sum().reindex(
#       2     ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
#       4 plt.figure(figsize=(8,5))
#       5 sales_by_day.plot(kind='bar', color='lightgreen')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Normalize column names
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]

# Step 2: Assume each row is one sale and create a dummy 'sale' column
df['sale'] = 1

# Step 3: Optionally create a day_of_week column if 'when' gives time of day, not weekday
# Since there's no actual date, we can't get 'Monday', 'Tuesday', etc.
# We'll use the 'when' column to simulate times of day
# You could skip this if you don't need it, or map it manually if needed

# Step 4: Group by 'when' (e.g., Morning, Afternoon, etc.)
sales_by_period = df.groupby('when')['sale'].sum()

# Step 5: Plot
plt.figure(figsize=(8,5))
sales_by_period.plot(kind='bar', color='lightgreen')
plt.title('Sales by Time of Day')
plt.xlabel('Time of Day')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sales_by_hour = df.groupby('hour')['total_price'].sum()

plt.figure(figsize=(10,5))
sales_by_hour.plot(kind='line', marker='o', color='orange')
plt.title("Sales by Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Total Sales")
plt.grid()
plt.tight_layout()
plt.savefig("/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/sales_by_hour.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sales_by_hour = df.groupby('hour')['total_price'].sum()
#       3 plt.figure(figsize=(10,5))
#       4 sales_by_hour.plot(kind='line', marker='o', color='orange')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/base.py:244, in SelectionMixin.__getitem__(self, key)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Clean column names
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]

# Convert gender to readable labels
df['gender_label'] = df['gender'].map({1.0: 'Male', 0.0: 'Female'})

# Group by gender and item
item_gender = df.groupby(['ordereditem', 'gender_label']).size().unstack().fillna(0)

# Take top 10 items overall
top_items = df['ordereditem'].value_counts().head(10).index
item_gender = item_gender.loc[top_items]

# Plot
item_gender.plot(kind='bar', stacked=True, figsize=(10,6), colormap='coolwarm')
plt.title('Top Ordered Items by Gender')
plt.xlabel('Item')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 11
#       8 df['gender_label'] = df['gender'].map({1.0: 'Male', 0.0: 'Female'})
#      10 # Group by gender and item
# ---> 11 item_gender = df.groupby(['ordereditem', 'gender_label']).size().unstack().fillna(0)
#      13 # Take top 10 items overall
#      14 top_items = df['ordereditem'].value_counts().head(10).index
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Clean column names again just in case
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]

# Convert gender column to readable labels
df['gender_label'] = df['gender'].map({1.0: 'Male', 0.0: 'Female'})

# Filter top 10 most popular items
top_items = df['ordereditem'].value_counts().head(10).index

# Filter dataset to include only those items
filtered_df = df[df['ordereditem'].isin(top_items)]

# Group by item and gender
item_gender = filtered_df.groupby(['ordereditem', 'gender_label']).size().unstack().fillna(0)

# Plot
item_gender.plot(kind='bar', stacked=True, figsize=(10,6), colormap='viridis')
plt.title('Top 10 Ordered Items by Gender')
plt.xlabel('Item')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ordereditem'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 11
# ...

# %%
import matplotlib.pyplot as plt

# Map gender to labels
df['gender_label'] = df['gender'].map({1.0: 'Male', 0.0: 'Female'})

# Group by gender and order_type
order_type_by_gender = df.groupby(['order_type', 'gender_label']).size().unstack().fillna(0)

# Plot
order_type_by_gender.plot(kind='bar', figsize=(8, 5), colormap='viridis')
plt.title("Order Type Distribution by Gender")
plt.xlabel("Order Type")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_items = df.groupby('item')['total_price'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
top_items.plot(kind='bar', color='plum')
plt.title("Top 10 Selling Items")
plt.ylabel("Total Sales")
plt.xlabel("Item")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/top_items.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 top_items = df.groupby('item')['total_price'].sum().sort_values(ascending=False).head(10)
#       3 plt.figure(figsize=(10,6))
#       4 top_items.plot(kind='bar', color='plum')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...

# %%
import matplotlib.pyplot as plt

# Get top 10 ordered items by count
top_items = df['ordereditem'].value_counts().head(10)

# Plot
plt.figure(figsize=(10,6))
top_items.plot(kind='bar', color='teal')
plt.title("Top 10 Ordered Items")
plt.xlabel("Item")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ordereditem'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 4
#       1 import matplotlib.pyplot as plt
# ...

# %%
# Replace 'ordereditem' with the actual column name from df.columns
top_items = df['<correct_column_name>'].value_counts().head(10)

plt.figure(figsize=(10, 6))
top_items.plot(kind='bar', color='teal')
plt.title('Top 10 Most Ordered Items')
plt.xlabel('Item')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '<correct_column_name>'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 2
# ...

# %%
print(df.columns.tolist())
# Out:
# ['age', 'gender', 'item', 'when', 'order_type', 'hour', 'date', 'day_of_week', 'sale', 'gender_label']

# %%
import matplotlib.pyplot as plt

# Get top 10 ordered items by count
top_items = df['item'].value_counts().head(10)

# Plot
plt.figure(figsize=(10, 6))
top_items.plot(kind='bar', color='teal')
plt.title('Top 10 Most Ordered Items')
plt.xlabel('Item')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# /Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project

# %%
os.makedirs("../visuals", exist_ok=True)

# %%
import matplotlib.pyplot as plt

# Example: simple dummy chart
plt.figure()
plt.plot([1, 2, 3], [10, 20, 15])
plt.title("Test Chart")
plt.savefig("../visuals/test_chart.png")
plt.show()

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project

# %%
os.chdir('/full/path/to/daily fastfood project/notebooks')  # <- replace this with the actual path
print("Changed working directory to:", os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 os.chdir('/full/path/to/daily fastfood project/notebooks')  # <- replace this with the actual path
#       2 print("Changed working directory to:", os.getcwd())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/full/path/to/daily fastfood project/notebooks'

# %%
import shutil
from glob import glob

# Create visuals folder if it doesn't exist
os.makedirs("../visuals", exist_ok=True)

# Find all PNG files in current notebook folder
png_files = glob("*.png")

# Copy each to visuals folder
for file in png_files:
    dest = os.path.join("../visuals", file)
    shutil.copy(file, dest)
    print(f"Copied: {file} → {dest}")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Optional: Rename column for clarity
df = df.rename(columns={'ordereditem': 'item'})

# Group and reshape
item_when = df.groupby(['when', 'item']).size().unstack().fillna(0)

# Set up plot
plt.figure(figsize=(12, 6))
item_when.plot(kind='bar', stacked=True, colormap='tab20', figsize=(12, 6))

# Labels and formatting
plt.title("Items Ordered by Time of Day")
plt.ylabel("Number of Orders")
plt.xlabel("Time of Day")
plt.xticks(rotation=0)
plt.tight_layout()

# Save to correct folder
save_path = "/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/items_by_time_of_day.png"
plt.savefig(save_path)

# Display plot
plt.show()

print(f"Image saved to: {save_path}")
# Out:
# Image saved to: /Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/items_by_time_of_day.png

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Normalize column names
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]

# Step 2: Create a dummy 'sale' column (1 per row)
df['sale'] = 1

# Step 3: Group by 'when' (e.g., Morning, Afternoon)
sales_by_period = df.groupby('when')['sale'].sum()

# Step 4: Plot
plt.figure(figsize=(8,5))
sales_by_period.plot(kind='bar', color='lightgreen')
plt.title('Sales by Time of Day')
plt.xlabel('Time of Day')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)
plt.tight_layout()

# Step 5: Save the plot
save_path = "/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/sales_by_time_of_day.png"
plt.savefig(save_path)

# Show the plot
plt.show()

print(f"Plot saved to: {save_path}")
# Out:
# Plot saved to: /Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/sales_by_time_of_day.png

# %%
import matplotlib.pyplot as plt

# Map gender to labels
df['gender_label'] = df['gender'].map({1.0: 'Male', 0.0: 'Female'})

# Group by gender and order_type
order_type_by_gender = df.groupby(['order_type', 'gender_label']).size().unstack().fillna(0)

# Plot
order_type_by_gender.plot(kind='bar', figsize=(8, 5), colormap='viridis')
plt.title("Order Type Distribution by Gender")
plt.xlabel("Order Type")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.tight_layout()

# Save to specified path
save_path = "/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/order_type_by_gender.png"
plt.savefig(save_path)

# Show the plot
plt.show()

print(f"Plot saved to: {save_path}")
# Out:
# Plot saved to: /Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/order_type_by_gender.png

# %%
import matplotlib.pyplot as plt

# Get top 10 ordered items by count
top_items = df['item'].value_counts().head(10)

# Plot
plt.figure(figsize=(10, 6))
top_items.plot(kind='bar', color='teal')
plt.title('Top 10 Most Ordered Items')
plt.xlabel('Item')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.tight_layout()

# Save to specified path
save_path = "/Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/top_10_items.png"
plt.savefig(save_path)

# Show the plot
plt.show()

print(f"Plot saved to: {save_path}")
# Out:
# Plot saved to: /Users/jenniferabhilash/Desktop/EUBS/Third Semester/daily fastfood project/visuals/top_10_items.png

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
